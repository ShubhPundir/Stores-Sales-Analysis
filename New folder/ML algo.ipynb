# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('final_df.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Item_Type'])
one_hot_encoded_data
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...

# %%
type(one_hot_encoded_data)
# Out:
# pandas.core.frame.DataFrame

# %%
X=one_hot_encoded_data.drop('Item_Outlet_Sales',axis=1)

# %%
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...

# %%
y=df['Item_Outlet_Sales']

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape)
y_train.shape
# Out:
# (5710, 24)
# (5710,)

# %%
y_test.shape
# Out:
# (2813,)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=5, random_state=0)

# %%
rfr = RandomForestRegressor(n_estimators=20, 
                             max_depth=3,
                             random_state=42)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)

# %%
y_pred
# Out:
# array([1219.81367438,  678.0557716 ,  678.0557716 , ..., 2833.05241984,
#        2977.39011086,  909.90926606])

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
rfr.score(X_test, y_test)
# Out:
# 0.3342013737711279

# %%
rfr.max_depth
# Out:
# 3

# %%
rfr.score(X_train,y_train)
# Out:
# 0.35798349511131167

# %%
from lazypredict.Supervised import LazyRegressor
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [37:07<00:00, 53.03s/it]

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor                0.51       0.51   1166.56
# LGBMRegressor                                0.51       0.51   1171.74
# GradientBoostingRegressor                    0.47       0.48   1208.59
# RandomForestRegressor                        0.46       0.46   1225.95
# XGBRegressor                                 0.45       0.46   1234.03
# BaggingRegressor                             0.40       0.41   1287.10
# ExtraTreesRegressor                          0.37       0.37   1324.59
# LassoCV                                      0.33       0.34   1361.17
# LarsCV                                       0.33       0.34   1361.21
# LassoLarsCV                                  0.33       0.34   1361.21
# OrthogonalMatchingPursuitCV                  0.33       0.34   1362.16
# LassoLarsIC                                  0.33       0.34   1362.18
# ...

# %%
predictions
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor                0.51       0.51   1166.56
# LGBMRegressor                                0.51       0.51   1171.74
# GradientBoostingRegressor                    0.47       0.48   1208.59
# RandomForestRegressor                        0.46       0.46   1225.95
# XGBRegressor                                 0.45       0.46   1234.03
# BaggingRegressor                             0.40       0.41   1287.10
# ExtraTreesRegressor                          0.37       0.37   1324.59
# LassoCV                                      0.33       0.34   1361.17
# LarsCV                                       0.33       0.34   1361.21
# LassoLarsCV                                  0.33       0.34   1361.21
# OrthogonalMatchingPursuitCV                  0.33       0.34   1362.16
# LassoLarsIC                                  0.33       0.34   1362.18
# ...

# %%
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...

# %%
X2=df.drop('Item_Outlet_Sales',axis=1)

# %%
y2=df['Item_Outlet_Sales']

# %%
y2
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.33, random_state=42)

# %%
rfr = RandomForestRegressor(n_estimators=20, 
                             max_depth=3,
                             random_state=42)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)

# %%
rfr.score(X_train,y_train)
# Out:
# 0.3579801283799643

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False),['Item_Type']),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
lr=LinearRegression(normalize=True)

# %%
pipe=make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
# ...

# %%
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.3358668372527315

# %%
len(X2['Item_Type'].unique())
# Out:
# 16

# %%
X2['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
X2
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.053931  182.0950
# 4           8.930                 1         0.053931   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     1            1                  1.00            1
# ...
