# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv('Train.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df=df[df['Item_Outlet_Sales']>0]

# %%
df=df[df['Item_Visibility']>0]

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1373
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2266
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import skew

# %%
df.select_dtypes(['int64','float64']).columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
for col in df.select_dtypes(['int64','float64']).columns:
    print(col)
    print(skew(df[col]))
    plt.figure()
    sns.distplot(df[col])
    plt.show()
# Out:
# Item_Weight
# nan
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Item_Visibility
# -0.4244783049103238
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Item_MRP
# 0.12288679329998671
# Outlet_Establishment_Year
# -0.39739316677840747
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Item_Outlet_Sales
# -0.8799911972416347
# C:\Users\Shubh Pundir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data=df.copy()

# %%
df['Item_Visibility']=np.log(df['Item_Visibility'])
df['Item_Outlet_Sales']=np.log(df['Item_Outlet_Sales'])

# %%
df['Item_Weight'].describe().reset_index()
# Out:
#    index  Item_Weight
# 0  count  6624.000000
# 1   mean    12.876462
# 2    std     4.644317
# 3    min     4.555000
# 4    25%     8.785000
# 5    50%    12.600000
# 6    75%    16.850000
# 7    max    21.350000

# %%
df['Item_Weight'].value_counts().reset_index().sort_values(by='index',ascending=False)
# Out:
#       index  Item_Weight
# 230  21.350            7
# 105  21.250           24
# 295  21.200            5
# 118  21.100           17
# 243  21.000            6
# ..      ...          ...
# 275   4.635            5
# 361   4.615            4
# 232   4.610            7
# 305   4.590            5
# 324   4.555            4
#
# [415 rows x 2 columns]

# %%
df['Item_Outlet_Sales'].describe()
# Out:
# count    7997.000000
# mean        7.295076
# std         1.016899
# min         3.505257
# 25%         6.720928
# 50%         7.492388
# 75%         8.038716
# max         9.479372
# Name: Item_Outlet_Sales, dtype: float64

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat        -4.132215
# 1              DRC01        5.920          Regular        -3.948780
# 2              FDN15       17.500          Low Fat        -4.088756
# 6              FDO10       13.650          Regular        -4.362923
# 7              FDP10          NaN          Low Fat        -2.059875
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat        -2.868511
# 8519           FDS36        8.380          Regular        -3.057982
# 8520           NCJ29       10.600          Low Fat        -3.347099
# 8521           FDN46        7.210          Regular        -1.929501
# 8522           DRG01       14.800          Low Fat        -3.103801
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# ...                  ...       ...               ...
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 6                          1987        High               Tier 3
# 7                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1           8.225540
# 1     Supermarket Type2           6.094524
# 2     Supermarket Type1           7.648392
# 6     Supermarket Type1           5.839341
# 7     Supermarket Type3           8.299724
# ...                 ...                ...
# 8518  Supermarket Type1           7.929625
# 8519  Supermarket Type1           6.308617
# 8520  Supermarket Type1           7.084322
# 8521  Supermarket Type2           7.520558
# 8522  Supermarket Type1           6.640751
#
# [7997 rows x 12 columns]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Item_Visibility']=df['Item_Visibility'].apply(lambda x:np.abs(x))

# %%
df.drop(['new'],axis=1,inplace=True)

# %%
df.drop(['Item_Identifier'],axis=1,inplace=True)

# %%
df
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0           9.300          Low Fat         4.132215               Dairy
# 1           5.920          Regular         3.948780         Soft Drinks
# 2          17.500          Low Fat         4.088756                Meat
# 6          13.650          Regular         4.362923         Snack Foods
# 7             NaN          Low Fat         2.059875         Snack Foods
# ...           ...              ...              ...                 ...
# 8518        6.865          Low Fat         2.868511         Snack Foods
# 8519        8.380          Regular         3.057982        Baking Goods
# 8520       10.600          Low Fat         3.347099  Health and Hygiene
# 8521        7.210          Regular         1.929501         Snack Foods
# 8522       14.800          Low Fat         3.103801         Soft Drinks
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                       1999      Medium
# 1      48.2692            OUT018                       2009      Medium
# 2     141.6180            OUT049                       1999      Medium
# 6      57.6588            OUT013                       1987        High
# 7     107.7622            OUT027                       1985      Medium
# ...        ...               ...                        ...         ...
# 8518  214.5218            OUT013                       1987        High
# 8519  108.1570            OUT045                       2002         NaN
# 8520   85.1224            OUT035                       2004       Small
# 8521  103.1332            OUT018                       2009      Medium
# 8522   75.4670            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1           8.225540
# 1                  Tier 3  Supermarket Type2           6.094524
# 2                  Tier 1  Supermarket Type1           7.648392
# 6                  Tier 3  Supermarket Type1           5.839341
# 7                  Tier 3  Supermarket Type3           8.299724
# ...                   ...                ...                ...
# 8518               Tier 3  Supermarket Type1           7.929625
# 8519               Tier 2  Supermarket Type1           6.308617
# 8520               Tier 2  Supermarket Type1           7.084322
# 8521               Tier 3  Supermarket Type2           7.520558
# 8522               Tier 1  Supermarket Type1           6.640751
#
# [7997 rows x 11 columns]

# %% [markdown]
# ### Imputing NaN values

# %%
df.isnull().sum()
# Out:
# Item_Weight                  1373
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2266
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_group = df.groupby(['Item_Type','Item_Fat_Content'],as_index=True).mean()['Item_Weight']

# %%
df_group=df_group.add_suffix('').reset_index()
df_group
# Out:
#         Item_Type Item_Fat_Content  Item_Weight
# 0    Baking Goods               LF    12.083462
# 1    Baking Goods          Low Fat    12.612065
# 2    Baking Goods          Regular    12.049606
# 3    Baking Goods          low fat    10.585000
# 4    Baking Goods              reg    12.825000
# ..            ...              ...          ...
# 64  Starchy Foods               LF    14.883333
# 65  Starchy Foods          Low Fat    13.753033
# 66  Starchy Foods          Regular    13.192093
# 67  Starchy Foods          low fat    14.150000
# 68  Starchy Foods              reg    12.375833
#
# [69 rows x 3 columns]

# %%
L=df[df['Item_Weight'].isnull()].index
fat_type=df['Item_Fat_Content'].unique()
item_type=df['Item_Type'].unique()
df_group = df.groupby(['Item_Type','Item_Fat_Content'],as_index=True).mean()['Item_Weight']
df_group=df_group.add_suffix('').reset_index()
for ind in L:
    for x in item_type:
        for y in fat_type:
            val=list(df_group[(df_group['Item_Fat_Content']==y) & (df_group['Item_Type']==x)]['Item_Weight'])
            if len(val)>0:
#                 df.loc[ind,'Item_Weight'] = np.where((df['Item_Fat_Content']==y) & (df['Item_Type'] == x), val[0], df['Item_Weight'])
                df.loc[ind,'Item_Weight'] = val

# %%
df['Outlet_Size'].fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Outlet_Establishment_Year']=df['Outlet_Establishment_Year'].astype('object')

# %%
df
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0         9.30000          Low Fat         4.132215               Dairy
# 1         5.92000          Regular         3.948780         Soft Drinks
# 2        17.50000          Low Fat         4.088756                Meat
# 6        13.65000          Regular         4.362923         Snack Foods
# 7        11.94125          Low Fat         2.059875         Snack Foods
# ...           ...              ...              ...                 ...
# 8518      6.86500          Low Fat         2.868511         Snack Foods
# 8519      8.38000          Regular         3.057982        Baking Goods
# 8520     10.60000          Low Fat         3.347099  Health and Hygiene
# 8521      7.21000          Regular         1.929501         Snack Foods
# 8522     14.80000          Low Fat         3.103801         Soft Drinks
#
#       Item_MRP Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                      1999      Medium
# 1      48.2692            OUT018                      2009      Medium
# 2     141.6180            OUT049                      1999      Medium
# 6      57.6588            OUT013                      1987        High
# 7     107.7622            OUT027                      1985      Medium
# ...        ...               ...                       ...         ...
# 8518  214.5218            OUT013                      1987        High
# 8519  108.1570            OUT045                      2002        High
# 8520   85.1224            OUT035                      2004       Small
# 8521  103.1332            OUT018                      2009      Medium
# 8522   75.4670            OUT046                      1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1           8.225540
# 1                  Tier 3  Supermarket Type2           6.094524
# 2                  Tier 1  Supermarket Type1           7.648392
# 6                  Tier 3  Supermarket Type1           5.839341
# 7                  Tier 3  Supermarket Type3           8.299724
# ...                   ...                ...                ...
# 8518               Tier 3  Supermarket Type1           7.929625
# 8519               Tier 2  Supermarket Type1           6.308617
# 8520               Tier 2  Supermarket Type1           7.084322
# 8521               Tier 3  Supermarket Type2           7.520558
# 8522               Tier 1  Supermarket Type1           6.640751
#
# [7997 rows x 11 columns]

# %%
data=df.copy()

# %%
data.to_csv('18Feb.csv')

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  7997.000000      7997.000000  7997.000000        7997.000000
# mean     12.715896         2.926025   141.181925           7.295076
# std       4.241501         0.787750    62.201545           1.016899
# min       4.555000         1.113550    31.290000           3.505257
# 25%       9.310000         2.321677    94.109400           6.720928
# 50%      11.941250         2.850899   143.215400           7.492388
# 75%      16.100000         3.460838   185.758200           8.038716
# max      21.350000         5.633875   266.888400           9.479372

# %%
df=data
df
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0         9.30000          Low Fat         4.132215               Dairy
# 1         5.92000          Regular         3.948780         Soft Drinks
# 2        17.50000          Low Fat         4.088756                Meat
# 6        13.65000          Regular         4.362923         Snack Foods
# 7        11.94125          Low Fat         2.059875         Snack Foods
# ...           ...              ...              ...                 ...
# 8518      6.86500          Low Fat         2.868511         Snack Foods
# 8519      8.38000          Regular         3.057982        Baking Goods
# 8520     10.60000          Low Fat         3.347099  Health and Hygiene
# 8521      7.21000          Regular         1.929501         Snack Foods
# 8522     14.80000          Low Fat         3.103801         Soft Drinks
#
#       Item_MRP Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                      1999      Medium
# 1      48.2692            OUT018                      2009      Medium
# 2     141.6180            OUT049                      1999      Medium
# 6      57.6588            OUT013                      1987        High
# 7     107.7622            OUT027                      1985      Medium
# ...        ...               ...                       ...         ...
# 8518  214.5218            OUT013                      1987        High
# 8519  108.1570            OUT045                      2002        High
# 8520   85.1224            OUT035                      2004       Small
# 8521  103.1332            OUT018                      2009      Medium
# 8522   75.4670            OUT046                      1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1           8.225540
# 1                  Tier 3  Supermarket Type2           6.094524
# 2                  Tier 1  Supermarket Type1           7.648392
# 6                  Tier 3  Supermarket Type1           5.839341
# 7                  Tier 3  Supermarket Type3           8.299724
# ...                   ...                ...                ...
# 8518               Tier 3  Supermarket Type1           7.929625
# 8519               Tier 2  Supermarket Type1           6.308617
# 8520               Tier 2  Supermarket Type1           7.084322
# 8521               Tier 3  Supermarket Type2           7.520558
# 8522               Tier 1  Supermarket Type1           6.640751
#
# [7997 rows x 11 columns]

# %% [markdown]
# ### NO OUTLIERS

# %%
from scipy import stats

# %%
df=df[(np.abs(stats.zscore(df['Item_Outlet_Sales']))<3)]

# %%
df=df[(np.abs(stats.zscore(df['Item_Weight']))<3)]

# %%
df=df[(np.abs(stats.zscore(df['Item_Visibility']))<3)]

# %%
df=df[(np.abs(stats.zscore(df['Item_MRP']))<3)]

# %%
df=df.reset_index()

# %%
df
# Out:
#       index  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0      9.30000          Low Fat         4.132215
# 1         1      5.92000          Regular         3.948780
# 2         2     17.50000          Low Fat         4.088756
# 3         6     13.65000          Regular         4.362923
# 4         7     11.94125          Low Fat         2.059875
# ...     ...          ...              ...              ...
# 7931   8518      6.86500          Low Fat         2.868511
# 7932   8519      8.38000          Regular         3.057982
# 7933   8520     10.60000          Low Fat         3.347099
# 7934   8521      7.21000          Regular         1.929501
# 7935   8522     14.80000          Low Fat         3.103801
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3            Snack Foods   57.6588            OUT013
# 4            Snack Foods  107.7622            OUT027
# ...                  ...       ...               ...
# 7931         Snack Foods  214.5218            OUT013
# 7932        Baking Goods  108.1570            OUT045
# 7933  Health and Hygiene   85.1224            OUT035
# 7934         Snack Foods  103.1332            OUT018
# 7935         Soft Drinks   75.4670            OUT046
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                         1999      Medium               Tier 1
# 1                         2009      Medium               Tier 3
# 2                         1999      Medium               Tier 1
# 3                         1987        High               Tier 3
# 4                         1985      Medium               Tier 3
# ...                        ...         ...                  ...
# 7931                      1987        High               Tier 3
# 7932                      2002        High               Tier 2
# 7933                      2004       Small               Tier 2
# 7934                      2009      Medium               Tier 3
# 7935                      1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1           8.225540
# 1     Supermarket Type2           6.094524
# 2     Supermarket Type1           7.648392
# 3     Supermarket Type1           5.839341
# 4     Supermarket Type3           8.299724
# ...                 ...                ...
# 7931  Supermarket Type1           7.929625
# 7932  Supermarket Type1           6.308617
# 7933  Supermarket Type1           7.084322
# 7934  Supermarket Type2           7.520558
# 7935  Supermarket Type1           6.640751
#
# [7936 rows x 12 columns]

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0         9.30000          Low Fat         4.132215               Dairy
# 1         5.92000          Regular         3.948780         Soft Drinks
# 2        17.50000          Low Fat         4.088756                Meat
# 3        13.65000          Regular         4.362923         Snack Foods
# 4        11.94125          Low Fat         2.059875         Snack Foods
# ...           ...              ...              ...                 ...
# 7931      6.86500          Low Fat         2.868511         Snack Foods
# 7932      8.38000          Regular         3.057982        Baking Goods
# 7933     10.60000          Low Fat         3.347099  Health and Hygiene
# 7934      7.21000          Regular         1.929501         Snack Foods
# 7935     14.80000          Low Fat         3.103801         Soft Drinks
#
#       Item_MRP Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                      1999      Medium
# 1      48.2692            OUT018                      2009      Medium
# 2     141.6180            OUT049                      1999      Medium
# 3      57.6588            OUT013                      1987        High
# 4     107.7622            OUT027                      1985      Medium
# ...        ...               ...                       ...         ...
# 7931  214.5218            OUT013                      1987        High
# 7932  108.1570            OUT045                      2002        High
# 7933   85.1224            OUT035                      2004       Small
# 7934  103.1332            OUT018                      2009      Medium
# 7935   75.4670            OUT046                      1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1           8.225540
# 1                  Tier 3  Supermarket Type2           6.094524
# 2                  Tier 1  Supermarket Type1           7.648392
# 3                  Tier 3  Supermarket Type1           5.839341
# 4                  Tier 3  Supermarket Type3           8.299724
# ...                   ...                ...                ...
# 7931               Tier 3  Supermarket Type1           7.929625
# 7932               Tier 2  Supermarket Type1           6.308617
# 7933               Tier 2  Supermarket Type1           7.084322
# 7934               Tier 3  Supermarket Type2           7.520558
# 7935               Tier 1  Supermarket Type1           6.640751
#
# [7936 rows x 11 columns]

# %% [markdown]
# ### X and Y

# %%
X=df.drop(['Item_Outlet_Sales'],axis=1)
y=df['Item_Outlet_Sales']

# %%
X
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0         9.30000          Low Fat         4.132215               Dairy
# 1         5.92000          Regular         3.948780         Soft Drinks
# 2        17.50000          Low Fat         4.088756                Meat
# 3        13.65000          Regular         4.362923         Snack Foods
# 4        11.94125          Low Fat         2.059875         Snack Foods
# ...           ...              ...              ...                 ...
# 7931      6.86500          Low Fat         2.868511         Snack Foods
# 7932      8.38000          Regular         3.057982        Baking Goods
# 7933     10.60000          Low Fat         3.347099  Health and Hygiene
# 7934      7.21000          Regular         1.929501         Snack Foods
# 7935     14.80000          Low Fat         3.103801         Soft Drinks
#
#       Item_MRP Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                      1999      Medium
# 1      48.2692            OUT018                      2009      Medium
# 2     141.6180            OUT049                      1999      Medium
# 3      57.6588            OUT013                      1987        High
# 4     107.7622            OUT027                      1985      Medium
# ...        ...               ...                       ...         ...
# 7931  214.5218            OUT013                      1987        High
# 7932  108.1570            OUT045                      2002        High
# 7933   85.1224            OUT035                      2004       Small
# 7934  103.1332            OUT018                      2009      Medium
# 7935   75.4670            OUT046                      1997       Small
#
#      Outlet_Location_Type        Outlet_Type
# 0                  Tier 1  Supermarket Type1
# 1                  Tier 3  Supermarket Type2
# 2                  Tier 1  Supermarket Type1
# 3                  Tier 3  Supermarket Type1
# 4                  Tier 3  Supermarket Type3
# ...                   ...                ...
# 7931               Tier 3  Supermarket Type1
# 7932               Tier 2  Supermarket Type1
# 7933               Tier 2  Supermarket Type1
# 7934               Tier 3  Supermarket Type2
# 7935               Tier 1  Supermarket Type1
#
# [7936 rows x 10 columns]

# %%
y
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       5.839341
# 4       8.299724
#           ...
# 7931    7.929625
# 7932    6.308617
# 7933    7.084322
# 7934    7.520558
# 7935    6.640751
# Name: Item_Outlet_Sales, Length: 7936, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
scaler=StandardScaler()

# %%
cat=['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
ohe=OneHotEncoder()
ohe.fit(X[cat])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),
                                      cat),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['LF', 'Low Fat', 'Regular', 'low fat', 'reg'], dtype=object),
#                                                                             array(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others...
#                                                                             array(['High', 'Medium', 'Small'], dtype=object),
#                                                                             array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object),
#                                                                             array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'], dtype=object)]),
#                                                   ['Item_Fat_Content',
#                                                    'Item_Type',
#                                                    'Outlet_Identifier',
#                                                    'Outlet_Establishment_Year',
#                                                    'Outlet_Size',
#                                                    'Outlet_Location_Type',
#                                                    'Outlet_Type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.682582077339245

# %%
scores=[]
for i in range(10000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
scores[np.argmax(scores)]
# Out:
# 0.7700670895857105

# %%
np.argmax(scores)
# Out:
# 20

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=20)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.7700670895857105
